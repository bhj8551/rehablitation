# %%
import pandas as pd

# %%
two_dimensional_list = [['dongwook', 50, 90], ['minsoo', 69, 38], ['mijin', 65, 98]]

# %%
my_df = pd.DataFrame(two_dimensional_list, columns=['name', 'english_score', 'math_score'])
my_df
# Out:
#        name  english_score  math_score
# 0  dongwook             50          90
# 1    minsoo             69          38
# 2     mijin             65          98

# %%
name_list = ['Taylor Swift', 'Aaron Sorkin', 'Harry Potter', 'Ji-Sung Park']
birth_list = ['December 13, 1989', 'June 9, 1961', 'July 31, 1980', 'February 25, 1981']
occupation_list = ['Singer-songwriter', 'Screenwriter', 'Wizard', 'Footballer']

my_dict = {
    'name': name_list,
    'birthday': birth_list,
    'occupation': occupation_list
}

df = pd.DataFrame(my_dict)
df
# Out:
#            name           birthday         occupation
# 0  Taylor Swift  December 13, 1989  Singer-songwriter
# 1  Aaron Sorkin       June 9, 1961       Screenwriter
# 2  Harry Potter      July 31, 1980             Wizard
# 3  Ji-Sung Park  February 25, 1981         Footballer

# %%
iphone_df = pd.read_csv('../data/iphone.csv', index_col=0)
iphone_df
# Out:
#                       출시일  디스플레이  메모리     출시 버전 Face ID
# iPhone 7       2016-09-16    4.7  2GB  iOS 10.0      No
# iPhone 7 Plus  2016-09-16    5.5  3GB  iOS 10.0      No
# iPhone 8       2017-09-22    4.7  2GB  iOS 11.0      No
# iPhone 8 Plus  2017-09-22    5.5  3GB  iOS 11.0      No
# iPhone X       2017-11-03    5.8  3GB  iOS 11.1     Yes
# iPhone XS      2018-09-21    5.8  4GB  iOS 12.0     Yes
# iPhone XS Max  2018-09-21    6.5  4GB  iOS 12.0     Yes

# %%
iphone_df = pd.read_csv('../data/iphone.csv', index_col=0)
iphone_df
# Out:
#                       출시일  디스플레이  메모리     출시 버전 Face ID
# iPhone 7       2016-09-16    4.7  2GB  iOS 10.0      No
# iPhone 7 Plus  2016-09-16    5.5  3GB  iOS 10.0      No
# iPhone 8       2017-09-22    4.7  2GB  iOS 11.0      No
# iPhone 8 Plus  2017-09-22    5.5  3GB  iOS 11.0      No
# iPhone X       2017-11-03    5.8  3GB  iOS 11.1     Yes
# iPhone XS      2018-09-21    5.8  4GB  iOS 12.0     Yes
# iPhone XS Max  2018-09-21    6.5  4GB  iOS 12.0     Yes

# %%
iphone_df.index.name = '제품명'
iphone_df
# Out:
#                       출시일  디스플레이  메모리     출시 버전 Face ID
# 제품명
# iPhone 7       2016-09-16    4.7  2GB  iOS 10.0      No
# iPhone 7 Plus  2016-09-16    5.5  3GB  iOS 10.0      No
# iPhone 8       2017-09-22    4.7  2GB  iOS 11.0      No
# iPhone 8 Plus  2017-09-22    5.5  3GB  iOS 11.0      No
# iPhone X       2017-11-03    5.8  3GB  iOS 11.1     Yes
# iPhone XS      2018-09-21    5.8  4GB  iOS 12.0     Yes
# iPhone XS Max  2018-09-21    6.5  4GB  iOS 12.0     Yes

# %%
iphone_df = pd.read_csv('../data/iphone.csv')
iphone_df
# Out:
#       Unnamed: 0         출시일  디스플레이  메모리     출시 버전 Face ID
# 0       iPhone 7  2016-09-16    4.7  2GB  iOS 10.0      No
# 1  iPhone 7 Plus  2016-09-16    5.5  3GB  iOS 10.0      No
# 2       iPhone 8  2017-09-22    4.7  2GB  iOS 11.0      No
# 3  iPhone 8 Plus  2017-09-22    5.5  3GB  iOS 11.0      No
# 4       iPhone X  2017-11-03    5.8  3GB  iOS 11.1     Yes
# 5      iPhone XS  2018-09-21    5.8  4GB  iOS 12.0     Yes
# 6  iPhone XS Max  2018-09-21    6.5  4GB  iOS 12.0     Yes

# %%
iphone_df.rename(columns={'Unnamed: 0':'상품명'}, inplace=True)
iphone_df
# Out:
#              상품명         출시일  디스플레이  메모리     출시 버전 Face ID
# 0       iPhone 7  2016-09-16    4.7  2GB  iOS 10.0      No
# 1  iPhone 7 Plus  2016-09-16    5.5  3GB  iOS 10.0      No
# 2       iPhone 8  2017-09-22    4.7  2GB  iOS 11.0      No
# 3  iPhone 8 Plus  2017-09-22    5.5  3GB  iOS 11.0      No
# 4       iPhone X  2017-11-03    5.8  3GB  iOS 11.1     Yes
# 5      iPhone XS  2018-09-21    5.8  4GB  iOS 12.0     Yes
# 6  iPhone XS Max  2018-09-21    6.5  4GB  iOS 12.0     Yes
